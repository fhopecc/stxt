# %%
import pandas as pd
pd.options.display.max_colwidth=0 #顯示全部字串
#總帳
g = pd.read_csv(r'D:\hlao\體育場會計報告審核\10805\cba\資料匯出-20190620142452-總分類帳.csv')
#付款憑單
cp = pd.read_csv(r'D:\hlao\體育場會計報告審核\10805\cba\資料匯出-20190620142452-付款憑單.csv')
#受款人檔
#r = pd.read_csv(r'D:\hlao\家教中心書審\家教中心108年5月會計月報\cba\資料匯出-20190619110325-受款人檔.csv')
cp.columns
# Out:
# Index(['主管機關代碼', '機關代碼', '機關編碼', '機關名稱', '會計年度', '送審月', '原屬年度', '預算來源', '會計分類',
#        '門別', '預算科目', '預算科目名稱', '用途別科目代碼', '用途別一級', '用途別二級', '用途別三級', '傳票日期',
#        '傳票類型', '傳票編號', '支出用途', '金額', '借貸', '送審年 '],
#       dtype='object')

# %%
#檢視收回款項
g1 = g[g['金額']==14550]
#g2 = g1[g1['原屬年度']==108]
g1
# Out:
#    主管機關代碼  機關代碼  機關編碼     機關名稱  會計年度  送審月  原屬年度 預算來源 會計分類    科目代號       科目名稱  \
# 4  4       900   9087  花蓮縣立體育場  108   1    107   應收數  歲入類  110303  應收款項-應收帳款
#
#       傳票日期    傳票類型             傳票編號              摘要       金額 借貸  送審年
# 4  1080101  分錄轉帳傳票  900141080000002  歲入類-上年度普通公務帳轉入  14550.0  借  108

# %%
#檢視收回款項
g1 = g[g['摘要'].str.contains('收回')]
#g2 = g1[g1['原屬年度']==108]
g1
# Out:
#      主管機關代碼  機關代碼  機關編碼     機關名稱  會計年度  送審月  原屬年度  預算來源 會計分類    科目代號  \
# 801  4       900   9087  花蓮縣立體育場  108   5    108   年度預算  經費類  510201
#
#           科目名稱     傳票日期  傳票類型             傳票編號             摘要      金額 借貸  送審年
# 801  人事支出-人事支出  1080529  收入傳票  900211080500044  收回溢發兼辦人事2月加班費  2500.0  貸  108

# %%
#代辦經費
g1 = g[g['科目名稱'].str.contains('代辦經費')]
#g2 = g1[g1['原屬年度']==108]
g1
# Out:
#      主管機關代碼  機關代碼  機關編碼     機關名稱  會計年度  送審月  原屬年度 預算來源 會計分類      科目代號  \
# 34   4       900   9087  花蓮縣立體育場  108   1    0     NaN  經費類  21130199
# 260  4       900   9087  花蓮縣立體育場  108   2    0     NaN  經費類  21130199
# 313  4       900   9087  花蓮縣立體育場  108   3    0     NaN  經費類  21130199
# 314  4       900   9087  花蓮縣立體育場  108   3    0     NaN  經費類  21130199
# 511  4       900   9087  花蓮縣立體育場  108   4    0     NaN  經費類  21130199
# 512  4       900   9087  花蓮縣立體育場  108   4    0     NaN  經費類  21130199
# 513  4       900   9087  花蓮縣立體育場  108   4    0     NaN  經費類  21130199
# 764  4       900   9087  花蓮縣立體育場  108   5    0     NaN  經費類  21130199
# 765  4       900   9087  花蓮縣立體育場  108   5    0     NaN  經費類  21130199
# 766  4       900   9087  花蓮縣立體育場  108   5    0     NaN  經費類  21130199
# 773  4       900   9087  花蓮縣立體育場  108   5    0     NaN  經費類  21130199
# 774  4       900   9087  花蓮縣立體育場  108   5    0     NaN  經費類  21130199
#
#            科目名稱     傳票日期    傳票類型             傳票編號  \
# ...

# %%
#收入歸屬年度錯誤
g1 = g[g['摘要'].str.contains('收入')]
g2 = g1[g1['原屬年度']==108]
#g3 = g2[~g2['摘要'].str.contains('不休假|電費|年終獎金|勞退金|考績獎金|教育補助費')]

#g4
#g3
#cp[cp['支出用途'].str.contains('冰水主機')]
g2
# Out:
#      主管機關代碼  機關代碼  機關編碼     機關名稱  會計年度  送審月  原屬年度  預算來源 會計分類    科目代號  \
# 155  4       900   9087  花蓮縣立體育場  108   1    108   年度預算  歲入類  410401
# 156  4       900   9087  花蓮縣立體育場  108   1    108   年度預算  歲入類  410401
# 157  4       900   9087  花蓮縣立體育場  108   1    108   年度預算  歲入類  410401
# 163  4       900   9087  花蓮縣立體育場  108   1    108   年度預算  歲入類  411901
# 165  4       900   9087  花蓮縣立體育場  108   1    108   年度預算  歲入類  510101
# 265  4       900   9087  花蓮縣立體育場  108   2    108   年度預算  歲入類  410401
# 266  4       900   9087  花蓮縣立體育場  108   2    108   年度預算  歲入類  410401
# 267  4       900   9087  花蓮縣立體育場  108   2    108   年度預算  歲入類  410401
# 268  4       900   9087  花蓮縣立體育場  108   2    108   年度預算  歲入類  411901
# 270  4       900   9087  花蓮縣立體育場  108   2    108   年度預算  歲入類  510101
# 434  4       900   9087  花蓮縣立體育場  108   3    108   年度預算  歲入類  410401
# 435  4       900   9087  花蓮縣立體育場  108   3    108   年度預算  歲入類  410401
# 436  4       900   9087  花蓮縣立體育場  108   3    108   年度預算  歲入類  410401
# ...

# %%
g[g['科目名稱'].str.contains('獎補助|其他')]
# Out:
#      主管機關代碼  機關代碼  機關編碼     機關名稱  會計年度  送審月  原屬年度  預算來源 會計分類       科目代號  \
# 163  4       900   9087  花蓮縣立體育場  108   1    108   年度預算  歲入類  411901
# 206  4       900   9087  花蓮縣立體育場  108   2    0     NaN   經費類  211301012
# 207  4       900   9087  花蓮縣立體育場  108   2    0     NaN   經費類  211301012
# 208  4       900   9087  花蓮縣立體育場  108   2    0     NaN   經費類  211301012
# 268  4       900   9087  花蓮縣立體育場  108   2    108   年度預算  歲入類  411901
# 354  4       900   9087  花蓮縣立體育場  108   3    0     NaN   經費類  211301012
# 358  4       900   9087  花蓮縣立體育場  108   3    0     NaN   經費類  211301012
# 509  4       900   9087  花蓮縣立體育場  108   4    0     NaN   經費類  211301012
# 510  4       900   9087  花蓮縣立體育場  108   4    0     NaN   經費類  211301012
# 655  4       900   9087  花蓮縣立體育場  108   4    108   年度預算  歲入類  411901
# 727  4       900   9087  花蓮縣立體育場  108   5    0     NaN   經費類  211301012
# 761  4       900   9087  花蓮縣立體育場  108   5    0     NaN   經費類  211301012
# ...

# %%
g[g['科目名稱'].str.contains('獎補助|其他')]

# %%
g[g['摘要'].str.contains('辦理')]
# Out:
#      主管機關代碼  機關代碼  機關編碼    機關名稱  會計年度  送審月  原屬年度  預算來源 會計分類      科目代號  \
# 131  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  110103
# 132  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  110901
# 133  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  110901
# 136  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  21130199
# 355  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  410101
# 364  4       600   9120  家庭教育中心  108   5    108   年度預算  經費類  510301
# 368  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  110103
# 369  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  110701
# 370  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  110701
# 377  4       600   9120  家庭教育中心  108   5    108   年度預算  經費類  510504
# 380  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  410101
# 382  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  410101
# 383  4       600   9120  家庭教育中心  108   5    108   年度預算  經費類  510504
#
# ...

# %%
r[r['傳票編號']==600251080500030]
# Out:
#      主管機關代碼  機關代碼  機關編碼    機關名稱  會計年度  送審月 會計分類             傳票編號     傳票日期  \
# 127  4       600   9120  家庭教育中心  108   5    經費類  600251080500030  1080516
#
#          序號  ...       受款人名稱            帳號     金融機構編號     金融機構名稱     支付金額  \
# 127  202008  ...  台灣應用劇場發展中心  8.535401e+11  8220853.0  中國信託南桃園分行  30000.0
#
#      (國庫)支票號碼 單據類別                地址          戶名  送審年
# 127  NaN       收據   臺北市北投區自強街61巷6號1樓  台灣應用劇場發展中心  108
#
# [1 rows x 21 columns]
