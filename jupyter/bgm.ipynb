# %%
#營業登記檔查核
import pandas as pd
import numpy as np
pd.options.display.max_colwidth=0 #顯示全部字串
#營業登記檔
bgm = pd.read_csv(r'c:\ais\\bgmopen1\BGMOPEN1.csv')
bgm = bgm.fillna(0)
bgm['統一編號']=bgm['統一編號'].astype('int')
bgm['總機構統一編號']=bgm['總機構統一編號'].astype('int')
bgm['設立日期']=bgm['設立日期'].astype('int')
bgm['行業代號']=bgm['行業代號'].astype('int')
bgm['行業代號1']=bgm['行業代號1'].astype('int')
bgm['行業代號2']=bgm['行業代號2'].astype('int')
bgm['行業代號3']=bgm['行業代號3'].astype('int')
bgm.dtypes

# %%
bgm[bgm['營業地址'].str.contains("花蓮縣")
   &(bgm['營業人名稱'].str.contains("農藥")
    |bgm['名稱'].str.contains("農藥")
    |bgm['名稱1'].str.contains("農藥")
    |bgm['名稱2'].str.contains("農藥")
    |bgm['名稱3'].str.contains("農藥") 
    )
   ].tocsv

# %%
bgm[bgm['營業地址'].str.contains("花蓮縣")
   &(bgm['營業人名稱'].str.contains("動物藥品")
    |bgm['名稱'].str.contains("動物藥品")
    |bgm['名稱1'].str.contains("動物藥品")
    |bgm['名稱2'].str.contains("動物藥品")
    |bgm['名稱3'].str.contains("動物藥品") 
    )
   ]
# Out:
#                             營業地址      統一編號  總機構統一編號    營業人名稱       資本額  \
# 1189888  花蓮縣吉安鄉北昌村２８鄰建國路１段１６６號１樓  49856306  0        富得行      450000.0
# 1192793  花蓮縣壽豐鄉壽豐村中山路６段１７４號１樓     67938646  0        向陽教育用品社  30000.0
# 1193571  花蓮縣壽豐鄉豐山村忠孝街１２巷８５弄１５號１樓  19530676  0        昇泰行      50000.0
# 1198978  花蓮縣花蓮市主學里上海街６３號          1822406   0        上海動物醫院   5000.0
# 1199390  花蓮縣花蓮市主工里０１２鄰民國路６１號１樓    67945560  0        愛加倍水族館   3000.0
# 1203865  花蓮縣花蓮市國魂里建國路１９６號１樓       37962513  0        華康藥局     5000.0
#
#             設立日期 組織別名稱 使用統一發票    行業代號       名稱   行業代號1     名稱1   行業代號2  \
# 1189888  940825   獨資    Y      485222  寵物飼品零售   454921  動物飼品批發  457114
# 1192793  870831   獨資    N      476112  書籍、雜誌零售  476111  文具零售    485222
# 1193571  850322   獨資    Y      485222  寵物飼品零售   475114  動物藥品零售  0
# 1198978  1020820  獨資    N      475114  動物藥品零售   0       0       0
# 1199390  880125   獨資    N      485220  寵物零售     485221  寵物用品零售  485222
# 1203865  1020301  獨資    N      475112  西藥零售     475113  醫療耗材零售  475114
#
#             名稱2   行業代號3          名稱3
# 1189888  動物藥品批發  0       0
# 1192793  寵物飼品零售  475114  動物藥品零售
# 1193571  0       0       0
# 1198978  0       0       0
# 1199390  寵物飼品零售  475114  動物藥品零售
# 1203865  動物藥品零售  475199  其他藥品及醫療用品零售
