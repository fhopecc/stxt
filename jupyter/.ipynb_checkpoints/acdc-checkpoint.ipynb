# %%
#動防所財抽
#營業登記
import pandas as pd
import numpy as np
import editdistance as ed
pd.options.display.max_colwidth=0 #顯示全部字串
#匯入農藥販賣業者
s1 = pd.read_excel(r'D:\gdrive\動防所108期中財抽\2.1.農藥販賣業執照核發情形\農藥販賣業執照批發.xls'
                  ,header=2
                  )
s1['營業種類']="批發"
s2=pd.read_excel(r'D:\gdrive\動防所108期中財抽\2.1.農藥販賣業執照核發情形\農藥販賣業執照零售.xls'
                  ,header=2
                  )
s2=s2[~s2['執照號碼'].isin(s1['執照號碼'])] #去除批發業者
s2['營業種類']="零售"

s=pd.concat([s1,s2],axis=0)
s.reset_index(drop=True, inplace=True)
s['商號地址'] = s['商號地址'].str.replace('1', '１')
s['商號地址'] = s['商號地址'].str.replace('2', '２')
s['商號地址'] = s['商號地址'].str.replace('3', '３')
s['商號地址'] = s['商號地址'].str.replace('4', '４')
s['商號地址'] = s['商號地址'].str.replace('5', '５')
s['商號地址'] = s['商號地址'].str.replace('6', '６')
s['商號地址'] = s['商號地址'].str.replace('7', '７')
s['商號地址'] = s['商號地址'].str.replace('8', '８')
s['商號地址'] = s['商號地址'].str.replace('9', '９')
s['商號地址'] = s['商號地址'].str.replace('0', '０')
s['商號名稱'] = s['商號名稱'].str.replace('新峰', '新峯')
s['商號名稱'] = s['商號名稱'].str.replace('金峰', '金峯')
s['商號名稱'] = s['商號名稱'].str.replace('惠民農藥行', '恵民農藥行')
s['商號名稱'] = s['商號名稱'].str.replace('廣益農葯行', '廣益農藥行')
#匯入營業登記檔
bgm = pd.read_csv(r'c:\ais\\bgmopen1\BGMOPEN1.csv')
bgm = bgm.fillna(0)
bgm['統一編號']=bgm['統一編號'].astype('int')
bgm['總機構統一編號']=bgm['總機構統一編號'].astype('int')
bgm['設立日期']=bgm['設立日期'].astype('int')
bgm['行業代號']=bgm['行業代號'].astype('int')
bgm['行業代號1']=bgm['行業代號1'].astype('int')
bgm['行業代號2']=bgm['行業代號2'].astype('int')
bgm['行業代號3']=bgm['行業代號3'].astype('int')
bgm.dtypes
bgm=bgm[bgm["營業地址"].str.contains("花蓮")]
#匯入預算明細分類帳
b = pd.read_csv(r'D:\gdrive\動防所108期中財抽\106_10807CBA\資料匯出-20190920083721-預算明細分類帳.csv'
               ,dtype={'金額':int})
b.columns

# %%
#農藥生化檢驗執行情形
bc106 = pd.read_excel(r'D:\gdrive\動防所108期中財抽\2.3.農藥殘留監控\生化檢驗月報\106年\106一覽表.xls'
                     ,header=1
                     )
bc106['年度']=106
bc107 = pd.read_excel(r'D:\gdrive\動防所108期中財抽\2.3.農藥殘留監控\生化檢驗月報\107年\107一覽表.xls'
                     ,header=1
                     )
bc107['年度']=107
bc108 = pd.read_excel(r'D:\gdrive\動防所108期中財抽\2.3.農藥殘留監控\生化檢驗月報\108年\108一覽表.xls'
                     ,header=1
                     )
bc108['年度']=108
bc = pd.concat([bc106, bc107, bc108], axis=0)
bc = bc.rename(columns={"Unnamed: 0": "月份", "Unnamed: 1": "統計項目"})
bc['月份'] = pd.Series(bc['月份']).fillna(method='ffill')
bc.at[24, '花蓮市農會']=0
#bc['花蓮市農會'] = bc['花蓮市農會'].str.replace(r'農委會農試所本\(108\)年度目僅到6月份','0')
#bc['花蓮市農會']=bc['花蓮市農會'].str.replace(r'\D+','0').fillna(0).astype(int)
bc = bc.fillna(0)
bcn = bc[bc['統計項目']!='不合格處理情形']

bcn.columns

# %%
bcy = pd.pivot_table(bcn
                    ,index=['年度', '統計項目']
                    ,values=[ '花蓮縣蔬菜運銷合作社'
                            ,'花蓮市農會', '吉安鄉農會' , '壽豐鄉農會', '光豐地區農會'
                            , '玉里鎮公所(檢驗稻穀)' , '富里鄉公所(檢驗稻穀)'
                            , '總合計'
                            ]
                    ,aggfunc={'總合計':np.sum
                             ,'花蓮縣蔬菜運銷合作社':np.sum
                             ,'花蓮市農會':np.sum
                             ,'吉安鄉農會':np.sum
                             ,'壽豐鄉農會':np.sum
                             ,'光豐地區農會':np.sum 
                             ,'玉里鎮公所(檢驗稻穀)':np.sum  
                             ,'富里鄉公所(檢驗稻穀)':np.sum 
                             }
                    ,fill_value=0
                    )
bcy.to_csv('fast_check.csv')

# %%
#匯出地址
#s['商號地址'].to_csv("store_addr.csv", encoding='cp950')
#s[s['倉儲地址'].str.len()>6]['倉儲地址'].to_csv("warhouse_addr.csv", encoding='cp950')

#取得倉儲地址土地使用配置
a1 = pd.read_csv(r'D:\gdrive\動防所108期中財抽\2.1.農藥販賣業執照核發情形\store_plan.csv')
a2 = pd.read_csv(r'D:\gdrive\動防所108期中財抽\2.1.農藥販賣業執照核發情形\warehouse_plan.csv')
a3 = pd.read_csv(r'D:\gdrive\動防所108期中財抽\2.1.農藥販賣業執照核發情形\store_cadastral.csv')
a4 = pd.read_csv(r'D:\gdrive\動防所108期中財抽\2.1.農藥販賣業執照核發情形\warehouse_cadastral.csv')
pl = pd.concat([a1,a2]).drop_duplicates().reset_index(drop=True)
ca = pd.concat([a3,a4]).drop_duplicates().reset_index(drop=True)
a1 = a1.drop('id',axis=1)
a2 = a2.drop('id',axis=1)
a3 = a3.drop('id',axis=1)
a4 = a4.drop('id',axis=1)
s=s.merge(pl, how='left', left_on='商號地址', right_on='Address')
s=s.merge(pl, how='left', left_on='倉儲地址', right_on='Address', suffixes=("_sp" , "_wp"))
s=s.merge(ca, how='left', left_on='商號地址', right_on='Address')
s=s.merge(ca, how='left', left_on='倉儲地址', right_on='Address', suffixes=("_sc", "_wc"))

#批發業者地址無效或未詳實填載者
s[ (s['營業種類']=='批發')
 & ( (s['倉儲地址'].str.len()<6)
   | (s['倉儲地址'].isna())
   | (s['Response_Address_wp'].str.contains("找不到"))
   )
 ][['執照號碼', '商號名稱', '分支機構', '商號統編', '商號電話', '負責人', '管理人員', '商號地址', '倉儲地址',
   '狀態', '執照發證日期', '停業/歇業/撤銷日期', '營業種類'
  ]].to_csv("ws_with_invalid_warhouse_address.csv")
#批發業者之倉儲地點位於住宅區者
s[ (s['營業種類']=='批發')
 & ((s['分區_sp']=='住宅區')
   |(s['分區_wp']=='住宅區')
   )
 ][['執照號碼', '商號名稱', '商號統編', '營業種類', '負責人', '商號地址', '倉儲地址', '執照發證日期', 
    '分區_sp', '都市計畫_sp',
    '分區_wp', '都市計畫_wp'
  ]].to_csv("ws_warhouse_in_ra.csv")
#業者之倉儲地點位於住宅區或商業區者
s[(s['分區_wp']=='住宅區')
 |(s['分區_wp']=='商業區')
 ][['執照號碼', '商號名稱', '商號統編', '營業種類', '負責人', '商號地址', '倉儲地址', '執照發證日期', 
    '分區_wp'
  ]].to_csv("warhouse_in_ra.csv")

s[~(s['AA12_sc'].str.contains('EA|EB|EC|ED', na=True)
   |s['AA12_wc'].str.contains('EA|EB|EC|ED', na=True)   
   )
 ][['執照號碼', '執照發證日期', '商號名稱', '商號統編', '營業種類', '負責人'
   ,'商號地址','PMNO_sc','PCNO_sc', 'SCNO_sc', 'AA12_sc'
   ,'倉儲地址','PMNO_wc','PCNO_wc', 'SCNO_wc', 'AA12_wc', 
  ]].drop_duplicates()

# %%
#匯出有座標的業者
s.dropna(subset=['Response_X']).to_csv("pesticide_seller.csv")

# %%
#匯出有效的倉儲地址
s[s['倉儲地址'].str.len()>6]['倉儲地址']

# %%
bgm[bgm['營業地址'].str.contains("花蓮縣")
   &(bgm['營業人名稱'].str.contains("農藥")
    |bgm['名稱'].str.contains("農藥")
    |bgm['名稱1'].str.contains("農藥")
    |bgm['名稱2'].str.contains("農藥")
    |bgm['名稱3'].str.contains("農藥") 
    )
   ]

# %%
url = "http://data.coa.gov.tw/Service/OpenData/FromM/AgricultureiResidueVegetable.aspx"
bad = pd.read_json(url)
bad.columns

# %%
bad[bad["採樣地點"].str.contains("花蓮")]

# %%
psbgm = bgm[ bgm['營業地址'].str.contains("花蓮縣")
           &(~bgm['營業人名稱'].str.contains('花蓮市農會|吉安鄉農會|富里鄉農會', na=False))
           &(bgm['名稱'].str.contains("農藥")
            |bgm['名稱1'].str.contains("農藥")
            |bgm['名稱2'].str.contains("農藥")
            |bgm['名稱3'].str.contains("農藥")
            )
           ]
bgm = bgm[ bgm['營業地址'].str.contains("花蓮縣")]
sib[sib['營業人名稱'].isnull()  
   |sib['商號名稱'].isnull()   
   ][['商號名稱', '營業人名稱', '商號地址', '營業地址']].count()#.to_csv('ps_bgm_check.csv')
#sib[['商號名稱', '營業人名稱']]

# %%
#計算名稱及地址編輯距離
s['k']=1
bgm['k']=1
sb = s.merge(bgm, on="k") # matrix product
sb["edn"] = sb.loc[:, ["商號名稱","營業人名稱"]].apply(lambda x: ed.eval(*x), axis=1)
sb["eda"] = sb.loc[:, ["商號地址","營業地址"]].apply(lambda x: ed.eval(*x), axis=1)

# %%
#農藥販賣執照商號地址與營業地址不同者
sb[(sb.groupby(['商號名稱'])['edn'].transform(min) == sb['edn'])
   &(sb['edn']<2)
   &(sb['eda']>3)
  ][[
    "執照號碼", "統一編號", '商號名稱', "營業人名稱", "edn"
  , "商號地址", "營業地址", "eda"
  ]].to_csv("sa_not_in_bga.csv")

# %%
#似未辦營登之農藥行 seller not in bgm
sb[(sb.groupby(['商號名稱'])['edn'].transform(min) == sb['edn'])
   &(sb['edn']>0)
  ][[
    "執照號碼" , '商號名稱', "營業人名稱", "edn"
  , "商號地址", "營業地址", "eda", '執照發證日期', '狀態', '停業/歇業/撤銷日期', "統一編號"
  ]]#.to_csv("s_not_in_bgm.csv")
# Out:
#                 執照號碼         商號名稱       營業人名稱  edn                       商號地址  \
# 445466   花蓮縣  O00087  花蓮縣富里鄉農會     花蓮縣瑞穗鄉農會    2    花蓮縣富里鄉富里村中山路１３５號
# 958951   花蓮縣  O00085  壽豐鄉農會豐田辦事處   壽豐鄉農會豐華再現館  4    花蓮縣壽豐鄉豐山村中山路２２２號
# 993331   花蓮縣  O00070  鳳榮地區農會林榮辦事處  鳳榮地區農會供銷部   5    花蓮縣鳳林鎮林榮里林榮路２１２號
# 993533   花蓮縣  O00070  鳳榮地區農會林榮辦事處  鳳榮地區農會      5    花蓮縣鳳林鎮林榮里林榮路２１２號
# 1014031  花蓮縣  O00071  鳳榮地區農會萬榮辦事處  鳳榮地區農會供銷部   5    花蓮縣鳳林鎮長橋里１１９號
# 1014233  花蓮縣  O00071  鳳榮地區農會萬榮辦事處  鳳榮地區農會      5    花蓮縣鳳林鎮長橋里１１９號
# 1065079  花蓮縣  O00080  光豐地區農會       玉溪地區農會      2    花蓮縣光復鄉大同村自強街１-１號
# 1076333  花蓮縣  O00080  光豐地區農會       鳳榮地區農會      2    花蓮縣光復鄉大同村自強街１-１號
# 1083633  花蓮縣  O00084  壽豐鄉農會        富里鄉農會       2    花蓮縣壽豐鄉壽豐村壽山路１９號
# 1104333  花蓮縣  O00006  吉安鄉農會        富里鄉農會       2    花蓮縣吉安鄉吉安村吉安路２段９０號
# 1130606  花蓮縣  O00083  花蓮市農會        花蓮縣農會       1    花蓮縣花蓮市國福里６４之７號
# 1221742  花蓮縣  O00017  惠鋒農藥行        光華農藥行       2    花蓮縣壽豐鄉豐山村中山路１４３號
# 1225049  花蓮縣  O00017  惠鋒農藥行        大勝農藥行       2    花蓮縣壽豐鄉豐山村中山路１４３號
# ...

# %%
#營業項目含農藥，卻未有農藥執照之營業人
sb[((sb.groupby(['營業人名稱'])['eda'].transform(min) == sb['eda'])
   |(sb.groupby(['營業人名稱'])['edn'].transform(min) == sb['edn'])
   )
   &(sb['名稱'].str.contains("農藥")
    |sb['名稱1'].str.contains("農藥")
    |sb['名稱2'].str.contains("農藥")
    |sb['名稱3'].str.contains("農藥") 
    )
   &(sb['edn']>0)
   &(sb['eda']>0)
  ][[
    "統一編號", "營業人名稱", '商號名稱', "edn"
    , "營業地址", "商號地址", "eda", "名稱", "名稱1", "名稱2", "名稱3"
  ]].sort_values("營業人名稱").to_csv("psbgm_not_in_ps.csv")

# %%
#農藥販賣執照商號地址與營業地址不同者
s.columns
# Out:
# Index(['執照號碼', '商號名稱', '分支機構', '商號統編', '商號電話', '負責人', '管理人員', '商號地址', '倉儲地址',
#        '狀態', '執照發證日期', '停業/歇業/撤銷日期', '營業種類', 'k'],
#       dtype='object')

# %%
#代噴業者管理
pe = pd.read_excel(r'D:\gdrive\動防所108期中財抽\2.4.代噴業者\代噴業者清冊.xlsx')
pe['鄉鎮市']=pe['住址'].str[3:6] 
pebycty = pe.groupby('鄉鎮市')
pebycty.count()
# Out:
#      申請人  身分證字號  農藥代噴技術人員訓練合格證書號碼  住址  申請日期  申請類別
# 鄉鎮市
# 卓溪鄉  1    1      1                 1   1     1
# 吉安鄉  1    1      1                 1   1     1
# 壽豐鄉  1    1      1                 1   1     1
# 富里鄉  1    1      1                 1   1     1
# 玉里鎮  6    6      6                 6   6     6
# 瑞穗鄉  1    1      1                 1   1     1
