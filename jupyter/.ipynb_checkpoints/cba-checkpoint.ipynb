# %%
import pandas as pd
pd.options.display.max_colwidth=0 #顯示全部字串
#總帳
g = pd.read_csv(r'D:\hlao\家教中心書審\家教中心108年5月會計月報\cba\資料匯出-20190619110325-總分類帳.csv')
g.columns
# Out:
# Index(['主管機關代碼', '機關代碼', '機關編碼', '機關名稱', '會計年度', '送審月', '原屬年度', '預算來源', '會計分類',
#        '科目代號', '科目名稱', '傳票日期', '傳票類型', '傳票編號', '摘要', '金額', '借貸', '送審年'],
#       dtype='object')

# %%
g[g['摘要'].str.contains('辦理')]
# Out:
#      主管機關代碼  機關代碼  機關編碼    機關名稱  會計年度  送審月  原屬年度  預算來源 會計分類      科目代號  \
# 131  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  110103
# 132  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  110901
# 133  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  110901
# 136  4       600   9120  家庭教育中心  108   2    0     NaN   經費類  21130199
# 355  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  410101
# 364  4       600   9120  家庭教育中心  108   5    108   年度預算  經費類  510301
# 368  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  110103
# 369  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  110701
# 370  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  110701
# 377  4       600   9120  家庭教育中心  108   5    108   年度預算  經費類  510504
# 380  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  410101
# 382  4       600   9120  家庭教育中心  108   5    0     NaN   經費類  410101
# 383  4       600   9120  家庭教育中心  108   5    108   年度預算  經費類  510504
#
# ...
