# %%
import pandas as pd
pd.options.display.max_colwidth=0 #顯示全部字串
#付款憑單-集中支付檔-cetralized payment
cp = pd.read_csv(r'D:\hlao\會計資訊檔案\ais\108_01_06\資料匯出-20190809143644-付款憑單明細檔.csv')
p108 = pd.read_csv(r'D:\hlao\會計資訊檔案\ais\108_01_06\資料匯出-20190809143644-明細分類帳.csv')
p107 = pd.read_csv(r'D:\hlao\會計資訊檔案\ais\107\資料匯出-20190615134322-明細分類帳.csv')
r = pd.read_excel(r'D:\hlao\會計資訊檔案\ais\108_01_06\資料匯出-20190809143644-收入傳票明細檔.xlsx')
ap=pd.read_csv(r'D:\hlao\會計資訊檔案\ais\108_01_06\資料匯出-20190809143644-請購單明細檔.csv')
p = pd.concat([p107,p108],axis=0)
p.columns
# Out:
# Index(['主管機關代碼', '審計部機關代碼', '機關編碼', '機關名稱', '送審年', '送審月', '年度', '縣市代碼',
#        '教育部機關代碼', '傳票類別代碼', '傳票類別名稱', '傳票號碼', '序號', '借貸方註記', '傳票日期', '金額',
#        '摘要', '總帳科目', '用途別代碼', '分支計畫代碼', '分支計畫名稱', '子目代碼', '子目名稱', '過帳日期',
#        '現金收入', '公庫存款收入', '來源傳票號碼', '固定資產修正用', '報廢或更新前期修正上一期', '用於固定項目傳票(9開頭)',
#        '經費來源', '經費來源名稱'],
#       dtype='object')

# %%
#列出期初應付代收-賠償
p[p['子目名稱'].str.contains('賠償',na=False)
 &p['摘要'].str.contains('結轉',na=False)
 ][['機關名稱','傳票類別名稱', '傳票號碼', '總帳科目', '子目代碼', '子目名稱', '過帳日期','摘要', '借貸方註記', '傳票日期', '金額',
   '來源傳票號碼', '經費來源', '經費來源名稱'
   ]
].sort_values(['機關名稱'],ascending=[False])
# Out:
#                機關名稱 傳票類別名稱  傳票號碼      總帳科目    子目代碼                     子目名稱  \
# 13183  花蓮縣花蓮市明義國民小學  轉帳傳票   0     2123      F00010  應付代收款-其他-公務賠償
# 13377  花蓮縣花蓮市明義國民小學  轉帳傳票   0     2123      F00010  應付代收款-其他-公務賠償
# 14338  花蓮縣花蓮市明廉國民小學  轉帳傳票   0     2123      B00011  應付代收款-學生繳費-公物賠償款
# 14293  花蓮縣花蓮市明廉國民小學  轉帳傳票   0     2123      B00010  應付代收款-學生繳費-賠償圖書款
# 14032  花蓮縣花蓮市明廉國民小學  轉帳傳票   0     2123      B00011  應付代收款-學生繳費-公物賠償款
# 13984  花蓮縣花蓮市明廉國民小學  轉帳傳票   0     2123      B00010  應付代收款-學生繳費-賠償圖書款
# 13838  花蓮縣花蓮市中正國民小學  轉帳傳票   0     2123      A00037  應付代收款-代收代付-賠償款
# 13538  花蓮縣花蓮市中正國民小學  轉帳傳票   0     2123      A00037  應付代收款-代收代付-賠償款
# 3423   花蓮縣立體育實驗高級中學  轉帳傳票   0     2123      F00008  應付代收款-其他-公物賠償
# 31024  (上期結轉)
# 31800  (上期結轉)
# 20723  (上期結轉)
# 21406  (上期結轉)
# 21079  (上期結轉)
# 22540  (上期結轉)
# 21741  (上期結轉)
# 18660  (上期結轉)
# 19136  (上期結轉)
# 18007  (上期結轉)
# 18028  (上期結轉)
# 18244  (上期結轉)
# 18744  (上期結轉)
#
#        借貸方註記     傳票日期       金額 來源傳票號碼  經費來源 經費來源名稱
# 13183  2      1070101  8740.0   00000 NaN    NaN
# 13377  2      1080101  8740.0   00000 NaN    NaN
# 14338  2      1080102  400.0    00000 NaN    NaN
# 14293  2      1080102  7690.0   00000 NaN    NaN
# 14032  2      1070103  200.0    00000 NaN    NaN
# 13984  2      1070103  2680.0   00000 NaN    NaN
# 13838  2      1080117  20493.0  00000 NaN    NaN
# 13538  2      1070101  24543.0  00000 NaN    NaN
# 3423   2      1070101  850.0    00000 NaN    NaN
# 2970   2      1080115  850.0    00000 NaN    NaN
# 4471   2      1070101  28709.0  00000 NaN    NaN
# 4169   2      1080112  11227.0  00000 NaN    NaN
# 5516   2      1070102  6286.0   00000 NaN    NaN
# 5171   2      1080102  8536.0   00000 NaN    NaN
# 3940   2      1070101  7314.0   00000 NaN    NaN
# 11946  2      1080104  7628.0   00000 NaN    NaN
# 11662  2      1070104  4078.0   00000 NaN    NaN
# 7058   2      1070101  4422.0   00000 NaN    NaN
# 6927   2      1080101  200.0    00000 NaN    NaN
# 6171   2      1080101  225.0    00000 NaN    NaN
# 6118   2      1080101  5375.0   00000 NaN    NaN
# 6297   2      1070101  225.0    00000 NaN    NaN
# 6242   2      1070101  9850.0   00000 NaN    NaN
# 5087   2      1070103  25481.0  00000 NaN    NaN
# 4754   2      1080104  14385.0  00000 NaN    NaN
# 5032   2      1070103  15555.0  00000 NaN    NaN
# 5642   2      1080101  400.0    00000 NaN    NaN
# 5901   2      1070102  100.0    00000 NaN    NaN
# 6748   2      1070101  28529.0  00000 NaN    NaN
# 6686   2      1080101  34184.0  00000 NaN    NaN
# 29717  2      1080110  440.0    00000 NaN    NaN
# 28648  2      1070106  240.0    00000 NaN    NaN
# 31024  2      1070106  670.0    00000 NaN    NaN
# 31800  2      1080105  970.0    00000 NaN    NaN
# 20723  2      1070124  370.0    00000 NaN    NaN
# 21406  2      1080101  370.0    00000 NaN    NaN
# 21079  2      1080103  1310.0   00000 NaN    NaN
# 22540  2      1080108  854.0    00000 NaN    NaN
# 21741  2      1070101  854.0    00000 NaN    NaN
# 18660  2      1070101  1586.0   00000 NaN    NaN
# 19136  2      1080101  1586.0   00000 NaN    NaN
# 18007  2      1080107  450.0    00000 NaN    NaN
# 18028  2      1080107  550.0    00000 NaN    NaN
# 18244  2      1070102  1880.0   00000 NaN    NaN
# 18744  2      1080103  1882.0   00000 NaN    NaN

# %%
p[p['摘要'].str.contains('賠償',na=False)
 &p['總帳科目'].str.contains('4',na=False)
 &p['子目名稱'].str.contains('賠償',na=False)
 ][['機關名稱','傳票類別名稱', '傳票號碼', '總帳科目', '子目代碼', '子目名稱','摘要', '借貸方註記', '傳票日期', '金額',
   '來源傳票號碼', '經費來源', '經費來源名稱'
   ]  
]
# Out:
#                機關名稱 傳票類別名稱  傳票號碼      總帳科目    子目代碼 子目名稱  \
# 59229  花蓮縣花蓮市中原國民小學  收入傳票   44    4YY               NaN
#
#                                                                                                          摘要  \
# 59229  學生書籍課本損壞賠償收入繳庫
#
#        借貸方註記     傳票日期    金額 來源傳票號碼  經費來源         經費來源名稱
# 59229  2      1080228  78.0         0.0   非特別經費來源(法定預算)

# %%
r[r['摘要'].str.contains('賠償收入繳庫',na=False)
 ][['機關名稱','傳票號碼', '傳票明細序號', '傳票類別代碼', '傳票類別名稱', '子目代碼', '子目名稱'
  ,'分支計畫代碼', '分支計畫名稱', '用途別代碼', '預計轉入科目代碼', '預計轉入子目代碼', '預計轉入子目名稱', '委受名稱'
  ,'摘要', '貸方金額', '原始憑證種類', '原始憑證號數', '貸方科目代碼', '經費來源', '經費來源名稱']
  ]
# Out:
#               機關名稱  傳票號碼  傳票明細序號 傳票類別代碼 傳票類別名稱    子目代碼 子目名稱            分支計畫代碼  \
# 9755  花蓮縣花蓮市中原國民小學  44    3       H      收入傳票           NaN
#
#      分支計畫名稱   用途別代碼  ... 預計轉入子目代碼 預計轉入子目名稱   委受名稱              摘要 貸方金額  \
# 9755  NaN            ...           NaN             學生書籍課本損壞賠償收入繳庫  78
#
#                     原始憑證種類      原始憑證號數    貸方科目代碼 經費來源         經費來源名稱
# 9755                                    4YY       0.0  非特別經費來源(法定預算)
#
# [1 rows x 21 columns]

# %%
ap[(ap['請購金額']==85289)]
# Out:
# Empty DataFrame
# Columns: [主管機關代碼, 審計部機關代碼, 機關編碼, 機關名稱, 送審年, 送審月, 年度, 縣市代碼, 教育部機關代碼, 請購單編號, 請購單明細序號, 總帳科目代碼, 子目, 子目名稱, 分支計畫代碼, 分支計畫名稱, 用途代碼, 用人費用類別代碼, 用人費用類別名稱, 請購部門代碼, 請購部門名稱, 簽證數, 請購金額, 摘要, 沖銷代碼]
# Index: []
#
# [0 rows x 25 columns]

# %%
ap[(ap['機關名稱'].str.contains(r"澔學",na=False))]
# Out:
#        主管機關代碼  審計部機關代碼   機關編碼      機關名稱  送審年  送審月   年度  縣市代碼  教育部機關代碼  請購單編號  \
# 15640  1       1        59356  花蓮縣政府教育處  108  2    108  15    15200    698
# 24270  1       1        59356  花蓮縣政府教育處  108  3    108  15    15200    921
#
#        ...      分支計畫名稱    用途代碼              用人費用類別代碼 用人費用類別名稱 請購部門代碼  \
# 15640  ...  教育局(處)其他設備  514     0                     NaN      03
# 24270  ...  NaN                 0                     NaN      03
#
#                 請購部門名稱        簽證數       請購金額  \
# 15640  教育網路中心           3239000.0  3239000.0
# 24270  教育網路中心           323900.0   323900.0
#
#                                                摘要 沖銷代碼
# 15640  支付澔學學習股份有限公司承攬花蓮縣智慧校園親師生平台及行動裝置APP採購案驗收撥款   1
# 24270  退還澔學學習股份有限公司承攬花蓮縣智慧校園親師生平台及行動裝置APP採購案履約保證金  1
#
# [2 rows x 25 columns]

# %%
#服裝費支付員工活動服裝
ap[(ap['用途代碼'].str.contains('325'))
  &(ap['摘要'].str.contains("服裝"))        
  ][['機關名稱','總帳科目代碼', '子目名稱', '分支計畫名稱','用途代碼', '摘要', '請購金額']]
# Out:
#            機關名稱    總帳科目代碼 子目名稱    分支計畫名稱    用途代碼  \
# 37061  花蓮縣政府教育處  571       NaN  體育管理及獎補助  325
#
#                                                摘要      請購金額
# 37061  支言瑞開發科技(股)花蓮縣108年大型運動賽會及參加全國性運動會服裝採購案第1批價金  515000.0

# %%
#以公款支付罰款
cp[cp['摘要'].str.contains('罰|滯|違|未足額進用')][['摘要']]
# Out:
#                                                                                                          摘要
# 888    付107年12月份未足額進用身障人員(陳文財)薪資及保險
# 4106   付108年1月未足額進用身障人員(陳文財)薪資及保險
# 6406   撥付明義國小「107學年度第2學期國民中小學簿本採購案」經費(扣違約金839)
# 7200   付108年2月未足額進用身障人員(陳文財)薪資及保險
# 11347  付108年3月未足額進用身障人員(陳文財)薪資及保險

# %%
#是否以非公關費支付餐敘、禮品
cp[(cp['摘要'].str.contains(r"招待|禮|餐"))
   &(~cp['摘要'].str.contains('學校午餐|貧困午餐|稽查|接力|賽|國手|白禮袋|廚工|代扣|設備|餐飲科|明禮|餐廳|慈輝|教室|誤餐|夜輔|廚房|典禮|學生|午餐秘書|姜禮誠|日誌'))
   &(~cp['用途別代嗎'].str.contains('291|27F'))
   ][['機關名稱','借方科目碼', '分支計畫名稱','用途別代嗎','摘要', '實付數', '預計轉入科目代碼']]
# Out:
#              機關名稱     借方科目碼        分支計畫名稱   用途別代嗎  \
# 345    花蓮縣政府教育處    571       體育管理及獎補助      221
# 705    花蓮縣立美崙國民中學  2125      NaN
# 706    花蓮縣立美崙國民中學  2125      NaN
# 1037   花蓮縣立鳳林國民中學  2125      NaN
# 1505   花蓮縣立南平中學    2125      NaN
# 3728   花蓮縣政府教育處    571       衛生管理及獎補助      32Y
# 6551   花蓮縣政府教育處    541       幼兒教育管理及獎補助    326
# 6712   花蓮縣政府教育處    5L1       基本行政工作維持      326
# 6713   花蓮縣政府教育處    532       國民小學學務管理及獎補助  326
# 11116  花蓮縣立國風國民中學  531       各校經常門分支計畫     326
# 11363  花蓮縣立宜昌國民中學  531       各校經常門分支計畫     326
#
#                                                                                                          摘要  \
# 345    支薛曉芸代墊郵資-郵寄體育署拜訪縣長伴手禮
# 705    付校長代墊校長室招待貴賓用茶杯
# 706    付校長代墊校長室招待貴賓用咖啡豆
# 1037   107年度文康活動餐點費-陳瑞蘭代墊
# 1505   跨年活動晚餐用瓦斯罐(12/31)-吳玟璇代墊
# 3728   支張韶容代墊刻印費-午餐廠商印章
# 6551   付首席烘焙坊50744553(負責人張書瑄)支108年快樂洄瀾兒童月系列活動?動記者會餐盒
# 6712   支游松基代墊教育處處務會議暨業務宣導務餐費
# 6713   支施淑娟代墊辦理本縣107學段第2次強迫入學委員會會議餐盒
# 11116  付德欣飯包店-107學年度第2學期教務處研習餐費
# 11363  2/14-15行政人員教育用餐-總-香又香
#
#            實付數  預計轉入科目代碼
# 345    255.0
# 705    3995.0
# 706    1300.0
# 1037   7980.0
# 1505   218.0
# 3728   600.0
# 6551   16000.0
# 6712   7910.0
# 6713   3200.0
# 11116  1600.0
# 11363  2900.0

# %%
ap.columns
# Out:
# Index(['主管機關代碼', '審計部機關代碼', '機關編碼', '機關名稱', '送審年', '送審月', '年度', '縣市代碼',
#        '教育部機關代碼', '請購單編號', '請購單明細序號', '總帳科目代碼', '子目', '子目名稱', '分支計畫代碼',
#        '分支計畫名稱', '用途代碼', '用人費用類別代碼', '用人費用類別名稱', '請購部門代碼', '請購部門名稱', '簽證數',
#        '請購金額', '摘要', '沖銷代碼'],
#       dtype='object')

# %%
#是否以非公關費支付餐敘、禮品
ap1 = ap[(~ap['用途代碼'].str.contains('291|27F'))
        &(ap['摘要'].str.contains("招待|禮"))        
        ]
ap2[(~ap2['摘要'].str.contains('學校午餐|書法營|畢業|門鎖|試辦計畫|白禮袋|家長|委員|期末|貧困午餐|兒童節|幼兒園|園遊會|稽查|活動|木工班|明禮|禮班|禮堂|接力|賽|國手|廚工|代扣|設備|體育班|義工|志工|餐飲科|餐廳|慈輝|教室|誤餐|夜輔|廚房|典禮|學生|午餐秘書|姜禮誠|日誌'))
  ][['機關名稱','總帳科目代碼', '子目名稱', '分支計畫名稱','用途代碼', '摘要', '請購金額']]
# Out:
#                機關名稱    總帳科目代碼                                   子目名稱  \
# 802    花蓮縣政府教育處      571       NaN
# 1038   花蓮縣立美崙國民中學    2125      NaN
# 1039   花蓮縣立美崙國民中學    2125      NaN
# 3286   花蓮縣立富源國民中學    2123      應付代收款-其他政府機關委託補助-萬榮鄉公所補助經費
# 3292   花蓮縣立富源國民中學    2123      應付代收款-其他政府機關委託補助-光復鄉公所補助經費
# 3297   花蓮縣立富源國民中學    2123      應付代收款-其他政府機關委託補助-其他-瑞穗鄉公所補
# 5189   花蓮縣花蓮市明廉國民小學  2123      應付代收款-其他-合唱團表演費
# 5196   花蓮縣花蓮市明廉國民小學  2123      應付代收款-教育處委託補助-終身教育科-教師節表揚大會經費
# 6159   花蓮縣花蓮市鑄強國民小學  532       NaN
# 6808   花蓮縣吉安鄉太昌國民小學  2123      應付代收款-民間團體委託補助-長育慈善基金會(運動)
# 8538   花蓮縣壽豐鄉月眉國民小學  532       NaN
# 38300  NaN                支同仁王佳楨禮金                                   57900.0
# 43485  NaN                預借辦理107學年村校聯合運動會獎品及禮券費(吳元芬預借.108.5.10清)    36485.0
# 46137  NaN                支108年村校聯合運動會-禮袋(黃嘉軒先行墊付)                   528.0
# 46730  NaN                支108年3月會議用水果禮盒                             750.0
# 47940  NaN                付108/3年度品德深耕-快閃伴手禮                         1480.0

# %%
#工程管理費超支
p1 = p[p['摘要'].str.contains('花崗國中Q棟',na=False)]
p1[~p1['摘要'].str.contains('保證')
  ][['機關名稱', '年度'
    , '教育部機關代碼', '傳票類別名稱', '傳票號碼', '序號', '借貸方註記', '傳票日期', '金額'
    ,'摘要', '總帳科目', '用途別代碼', '分支計畫代碼', '分支計畫名稱', '子目代碼', '子目名稱'
    , '過帳日期', '經費來源', '經費來源名稱']]
# Out:
#           機關名稱   年度  教育部機關代碼 傳票類別名稱  傳票號碼        序號  借貸方註記     傳票日期  \
# 235   花蓮縣政府教育處  108  15200    付款憑單   90    0         2      1080110
# 236   花蓮縣政府教育處  108  15200    付款憑單   90    1         1      1080110
# 1608  花蓮縣政府教育處  108  15200    支出傳票   36    0         2      1080114
# 1609  花蓮縣政府教育處  108  15200    支出傳票   36    1         1      1080114
# 2497  花蓮縣政府教育處  108  15200    轉帳傳票   20    13108365  1      1080131
# 2535  花蓮縣政府教育處  108  15200    轉帳傳票   20    13108933  2      1080131
#
#              金額  \
# 235   408350.0
# 236   408350.0
# 1608  3675150.0
# 1609  3675150.0
# 2497  408350.0
# 2535  408350.0
#
#                                                                                                         摘要  \
# 235   1070226府主審1070036522花崗國中Q棟104年第一階段校舍補強工程-支平順土木包工業工程款
# 236   花崗國中Q棟104年第一階段校舍補強工程-支平順土木包工業工程款107府主審36522(104)
# 1608  1070226府主審1070036522花崗國中Q棟104年第一階段校舍補強工程-支平順土木包工業工程款
# 1609  花崗國中Q棟104年第一階段校舍補強工程-支平順土木包工業工程款
# 2497  花崗國中Q棟104年第一階段校舍補強工程-支平順土木包工業工程款
# 2535  花崗國中Q棟104年第一階段校舍補強工程-支平順土木包工業工程款
#
#           總帳科目   用途別代碼            分支計畫代碼 分支計畫名稱    子目代碼  \
# 235   1112-01                             NaN
# 236   1154                                NaN
# 1608  1112-02                             NaN
# 1609  2123                                NaN    04B063
# 2497  2129                                NaN    07RP24
# 2535  1154                                NaN
#
#                                         子目名稱     過帳日期  經費來源         經費來源名稱
# 235   NaN                                     1080110 NaN    NaN
# 236   NaN                                     1080110  1.0   保留款
# 1608  NaN                                     1080118 NaN    NaN
# 1609  應付代收款-教育部-104年度第一階段公立國中小校舍補強工程經費        1080118  0.0   非特別經費來源(法定預算)
# 2497  應付工程款-花崗國中Q棟104年第一階段校舍補強工程-支平順土木包工業工程款  1080307  0.0   非特別經費來源(法定預算)
# 2535  NaN                                     1080307  0.0   非特別經費來源(法定預算)
